# %%
# Import important library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Read the input file and check the data dimension

# %%
GermanCredit = pd.read_csv('german_credit.csv')
GermanCredit.sample(5).T
# Out:
#                                                                           136  \
# default                                                                     0
# account_check_status                                      no checking account
# duration_in_month                                                          27
# credit_history                                delay in paying off in the past
# purpose                                                            car (used)
# credit_amount                                                            8613
# savings                                                        .. >= 1000 DM
# present_emp_since                                          1 <= ... < 4 years
# installment_as_income_perc                                                  2
# personal_status_sex                                             male : single
# other_debtors                                                            none
# present_res_since                                                           2
# property                    if not A121/A122 : car or other, not in attrib...
# age                                                                        27
# other_installment_plans                                                  none
# housing                                                                   own
# credits_this_bank                                                           2
# job                                               skilled employee / official
# people_under_maintenance                                                    1
# telephone                                                                none
# foreign_worker                                                            yes
#
#                                                                           158  \
# default                                                                     0
# account_check_status                                        0 <= ... < 200 DM
# duration_in_month                                                          24
# credit_history                       existing credits paid back duly till now
# purpose                                                             car (new)
# credit_amount                                                            3512
# savings                                                   100 <= ... < 500 DM
# present_emp_since                                          4 <= ... < 7 years
# installment_as_income_perc                                                  2
# personal_status_sex                                             male : single
# other_debtors                                                            none
# present_res_since                                                           3
# property                    if not A121/A122 : car or other, not in attrib...
# age                                                                        38
# other_installment_plans                                                  bank
# housing                                                                   own
# credits_this_bank                                                           2
# job                                               skilled employee / official
# people_under_maintenance                                                    1
# telephone                           yes, registered under the customers name
# foreign_worker                                                            yes
#
#                                                                           587  \
# default                                                                     0
# account_check_status                                                   < 0 DM
# duration_in_month                                                          12
# credit_history                       existing credits paid back duly till now
# purpose                                                      radio/television
# credit_amount                                                            1289
# savings                                                          ... < 100 DM
# present_emp_since                                          1 <= ... < 4 years
# installment_as_income_perc                                                  4
# personal_status_sex                                             male : single
# other_debtors                                                       guarantor
# present_res_since                                                           1
# property                    if not A121 : building society savings agreeme...
# age                                                                        21
# other_installment_plans                                                  none
# housing                                                                   own
# credits_this_bank                                                           1
# job                                                      unskilled - resident
# people_under_maintenance                                                    1
# telephone                                                                none
# foreign_worker                                                            yes
#
#                                                                           991  \
# default                                                                     0
# account_check_status                                      no checking account
# duration_in_month                                                          15
# credit_history                        all credits at this bank paid back duly
# purpose                                                   domestic appliances
# credit_amount                                                            1569
# savings                                                   100 <= ... < 500 DM
# present_emp_since                                               .. >= 7 years
# installment_as_income_perc                                                  4
# personal_status_sex                                             male : single
# other_debtors                                                            none
# present_res_since                                                           4
# property                    if not A121/A122 : car or other, not in attrib...
# age                                                                        34
# other_installment_plans                                                  bank
# housing                                                                   own
# credits_this_bank                                                           1
# job                                                      unskilled - resident
# people_under_maintenance                                                    2
# telephone                                                                none
# foreign_worker                                                            yes
#
#                                                                           509
# default                                                                     0
# account_check_status                                      no checking account
# duration_in_month                                                          39
# credit_history                       existing credits paid back duly till now
# purpose                                                            car (used)
# credit_amount                                                            8588
# savings                                                   100 <= ... < 500 DM
# present_emp_since                                               .. >= 7 years
# installment_as_income_perc                                                  4
# personal_status_sex                                             male : single
# other_debtors                                                            none
# present_res_since                                                           2
# property                    if not A121/A122 : car or other, not in attrib...
# age                                                                        45
# other_installment_plans                                                  none
# housing                                                                   own
# credits_this_bank                                                           1
# job                         management/ self-employed/ highly qualified em...
# people_under_maintenance                                                    1
# telephone                           yes, registered under the customers name
# foreign_worker                                                            yes

# %%
# You can access from https://www.kaggle.com/uciml/german-credit
#Read input file and understand the data
# "default" is my dependent variable
# Out:
# (1000, 21)
# Index(['default', 'account_check_status', 'duration_in_month',
#        'credit_history', 'purpose', 'credit_amount', 'savings',
#        'present_emp_since', 'installment_as_income_perc',
#        'personal_status_sex', 'other_debtors', 'present_res_since', 'property',
#        'age', 'other_installment_plans', 'housing', 'credits_this_bank', 'job',
#        'people_under_maintenance', 'telephone', 'foreign_worker'],
#       dtype='object')
#    default account_check_status  duration_in_month  \
# 0        0               < 0 DM                  6
# 1        1    0 <= ... < 200 DM                 48
# 2        0  no checking account                 12
# 3        0               < 0 DM                 42
# 4        1               < 0 DM                 24
#
#                                       credit_history  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#                         purpose  credit_amount                      savings  \
# 0           domestic appliances           1169  unknown/ no savings account
# 1           domestic appliances           5951                 ... < 100 DM
# 2  (vacation - does not exist?)           2096                 ... < 100 DM
# 3              radio/television           7882                 ... < 100 DM
# 4                     car (new)           4870                 ... < 100 DM
#
#     present_emp_since  installment_as_income_perc  \
# 0       .. >= 7 years                           4
# 1  1 <= ... < 4 years                           2
# 2  4 <= ... < 7 years                           2
# 3  4 <= ... < 7 years                           2
# 4  1 <= ... < 4 years                           3
#
#                    personal_status_sex      ...       present_res_since  \
# 0                        male : single      ...                       4
# 1  female : divorced/separated/married      ...                       2
# 2                        male : single      ...                       3
# 3                        male : single      ...                       4
# 4                        male : single      ...                       4
#
#                                             property age  \
# 0                                        real estate  67
# 1                                        real estate  22
# 2                                        real estate  49
# 3  if not A121 : building society savings agreeme...  45
# 4                              unknown / no property  53
#
#    other_installment_plans   housing credits_this_bank  \
# 0                     none       own                 2
# 1                     none       own                 1
# 2                     none       own                 1
# 3                     none  for free                 1
# 4                     none  for free                 2
#
#                            job people_under_maintenance  \
# 0  skilled employee / official                        1
# 1  skilled employee / official                        1
# 2         unskilled - resident                        2
# 3  skilled employee / official                        2
# 4  skilled employee / official                        2
#
#                                    telephone foreign_worker
# 0  yes, registered under the customers name             yes
# 1                                       none            yes
# 2                                       none            yes
# 3                                       none            yes
# 4                                       none            yes
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Q1 Randomly select 50% data for this use case( 1 Marks)
# ###### Hint: Use train_test_split

# %%
#X = GermanCredit.drop("default", axis=1)
y = GermanCredit["default"]

# %%
GermanCredit_train, GermanCredit_test , y_train, y_test = train_test_split(GermanCredit,y,test_size = 0.50 , random_state = 7)

# %%
# Lets build a Ensemble model but need to modify the dataset first

# %% [markdown]
# ### Q2.Prepare the model data by converting non-numeric to dummy ( 1 Marks)
# ##### Hint: Use get_dummies

# %%
# Print Shape of model data
GermanCredit.shape
GermanCredit_train.shape
#GermanCredit_train data have the complete columns as per the original dataset with half no of records.
# Out:
# (500, 21)

# %%
GermanCredit_train_D = pd.get_dummies(GermanCredit_train)
GermanCredit_train_D.head(5).T
# Out:
#                                                      262   457   82     563  \
# default                                                0     1     0      1
# duration_in_month                                     18    12    18     36
# credit_amount                                       5302  3386  1568  12389
# installment_as_income_perc                             2     3     3      1
# present_res_since                                      4     4     4      4
# age                                                   36    35    24     37
# credits_this_bank                                      3     1     1      1
# people_under_maintenance                               1     1     1      1
# account_check_status_0 <= ... < 200 DM                 0     0     0      1
# account_check_status_< 0 DM                            1     1     0      0
# account_check_status_>= 200 DM / salary assignm...     0     0     0      0
# account_check_status_no checking account               0     0     1      0
# credit_history_all credits at this bank paid ba...     0     0     0      0
# credit_history_critical account/ other credits ...     1     0     0      0
# credit_history_delay in paying off in the past         0     0     0      0
# credit_history_existing credits paid back duly ...     0     1     1      1
# credit_history_no credits taken/ all credits pa...     0     0     0      0
# purpose_(vacation - does not exist?)                   0     0     0      0
# purpose_business                                       0     0     1      0
# purpose_car (new)                                      1     0     0      1
# purpose_car (used)                                     0     1     0      0
# purpose_domestic appliances                            0     0     0      0
# purpose_education                                      0     0     0      0
# purpose_furniture/equipment                            0     0     0      0
# purpose_radio/television                               0     0     0      0
# purpose_repairs                                        0     0     0      0
# purpose_retraining                                     0     0     0      0
# savings_.. >= 1000 DM                                  0     0     0      0
# savings_... < 100 DM                                   1     1     0      0
# savings_100 <= ... < 500 DM                            0     0     1      0
# ...                                                  ...   ...   ...    ...
# present_emp_since_.. >= 7 years                        1     1     0      0
# present_emp_since_... < 1 year                         0     0     0      0
# present_emp_since_1 <= ... < 4 years                   0     0     1      1
# present_emp_since_4 <= ... < 7 years                   0     0     0      0
# present_emp_since_unemployed                           0     0     0      0
# personal_status_sex_female : divorced/separated...     0     0     1      0
# personal_status_sex_male : divorced/separated          0     0     0      0
# personal_status_sex_male : married/widowed             0     0     0      0
# personal_status_sex_male : single                      1     1     0      1
# other_debtors_co-applicant                             0     0     0      0
# other_debtors_guarantor                                0     0     0      0
# other_debtors_none                                     1     1     1      1
# property_if not A121 : building society savings...     0     0     1      0
# property_if not A121/A122 : car or other, not i...     0     0     0      0
# property_real estate                                   0     0     0      0
# property_unknown / no property                         1     1     0      1
# other_installment_plans_bank                           0     0     0      0
# other_installment_plans_none                           1     1     1      1
# other_installment_plans_stores                         0     0     0      0
# housing_for free                                       1     1     0      1
# housing_own                                            0     0     0      0
# housing_rent                                           0     0     1      0
# job_management/ self-employed/ highly qualified...     1     0     0      0
# job_skilled employee / official                        0     1     0      1
# job_unemployed/ unskilled - non-resident               0     0     0      0
# job_unskilled - resident                               0     0     1      0
# telephone_none                                         0     0     1      0
# telephone_yes, registered under the customers n...     1     1     0      1
# foreign_worker_no                                      0     0     0      0
# foreign_worker_yes                                     1     1     1      1
#
#                                                      407
# default                                                0
# duration_in_month                                     15
# credit_amount                                       1053
# installment_as_income_perc                             4
# present_res_since                                      2
# age                                                   27
# credits_this_bank                                      1
# people_under_maintenance                               1
# account_check_status_0 <= ... < 200 DM                 0
# account_check_status_< 0 DM                            1
# account_check_status_>= 200 DM / salary assignm...     0
# account_check_status_no checking account               0
# credit_history_all credits at this bank paid ba...     0
# credit_history_critical account/ other credits ...     0
# credit_history_delay in paying off in the past         0
# credit_history_existing credits paid back duly ...     1
# credit_history_no credits taken/ all credits pa...     0
# purpose_(vacation - does not exist?)                   0
# purpose_business                                       0
# purpose_car (new)                                      0
# purpose_car (used)                                     0
# purpose_domestic appliances                            1
# purpose_education                                      0
# purpose_furniture/equipment                            0
# purpose_radio/television                               0
# purpose_repairs                                        0
# purpose_retraining                                     0
# savings_.. >= 1000 DM                                  0
# savings_... < 100 DM                                   1
# savings_100 <= ... < 500 DM                            0
# ...                                                  ...
# present_emp_since_.. >= 7 years                        0
# present_emp_since_... < 1 year                         1
# present_emp_since_1 <= ... < 4 years                   0
# present_emp_since_4 <= ... < 7 years                   0
# present_emp_since_unemployed                           0
# personal_status_sex_female : divorced/separated...     0
# personal_status_sex_male : divorced/separated          0
# personal_status_sex_male : married/widowed             1
# personal_status_sex_male : single                      0
# other_debtors_co-applicant                             0
# other_debtors_guarantor                                0
# other_debtors_none                                     1
# property_if not A121 : building society savings...     0
# property_if not A121/A122 : car or other, not i...     0
# property_real estate                                   1
# property_unknown / no property                         0
# other_installment_plans_bank                           0
# other_installment_plans_none                           1
# other_installment_plans_stores                         0
# housing_for free                                       0
# housing_own                                            1
# housing_rent                                           0
# job_management/ self-employed/ highly qualified...     0
# job_skilled employee / official                        1
# job_unemployed/ unskilled - non-resident               0
# job_unskilled - resident                               0
# telephone_none                                         1
# telephone_yes, registered under the customers n...     0
# foreign_worker_no                                      1
# foreign_worker_yes                                     0
#
# [62 rows x 5 columns]

# %% [markdown]
# ### Check for highly correlated variables but don't required any treatment for this use case

# %%
GermanCredit_train_D.isna().any(axis=None)

## .isna().any(axis=None) this funnction give the result as true if any of the value are NAN or null in the complete dataset .
## .isna().any(axis=0) this function will list all the columns wih value as false if no NAN value or true for any nan value .
# Out:
# False

# %%
GermanCredit_train_D.corr()
# Out:
#                                                      default  \
# default                                             1.000000
# duration_in_month                                   0.259089
# credit_amount                                       0.218535
# installment_as_income_perc                          0.053474
# present_res_since                                  -0.041841
# age                                                -0.081586
# credits_this_bank                                  -0.061375
# people_under_maintenance                           -0.007916
# account_check_status_0 <= ... < 200 DM              0.116593
# account_check_status_< 0 DM                         0.245368
# account_check_status_>= 200 DM / salary assignm... -0.013116
# account_check_status_no checking account           -0.325050
# credit_history_all credits at this bank paid ba...  0.132678
# credit_history_critical account/ other credits ... -0.179608
# credit_history_delay in paying off in the past      0.001979
# credit_history_existing credits paid back duly ...  0.064564
# credit_history_no credits taken/ all credits pa...  0.110853
# purpose_(vacation - does not exist?)                0.149010
# purpose_business                                    0.052381
# purpose_car (new)                                   0.046252
# purpose_car (used)                                 -0.121546
# purpose_domestic appliances                        -0.142107
# purpose_education                                  -0.010344
# purpose_furniture/equipment                         0.016760
# purpose_radio/television                            0.085950
# purpose_repairs                                     0.016760
# purpose_retraining                                 -0.012383
# savings_.. >= 1000 DM                              -0.017936
# savings_... < 100 DM                                0.147265
# savings_100 <= ... < 500 DM                        -0.011193
# ...                                                      ...
# present_emp_since_.. >= 7 years                    -0.025449
# present_emp_since_... < 1 year                      0.113265
# present_emp_since_1 <= ... < 4 years                0.008999
# present_emp_since_4 <= ... < 7 years               -0.108070
# present_emp_since_unemployed                        0.016482
# personal_status_sex_female : divorced/separated...  0.099384
# personal_status_sex_male : divorced/separated       0.113269
# personal_status_sex_male : married/widowed         -0.053148
# personal_status_sex_male : single                  -0.109740
# other_debtors_co-applicant                          0.057146
# other_debtors_guarantor                            -0.077210
# other_debtors_none                                  0.012412
# property_if not A121 : building society savings...  0.024887
# property_if not A121/A122 : car or other, not i...  0.018070
# property_real estate                               -0.150162
# property_unknown / no property                      0.136669
# other_installment_plans_bank                        0.121287
# other_installment_plans_none                       -0.131682
# other_installment_plans_stores                      0.043955
# housing_for free                                    0.091346
# housing_own                                        -0.158921
# housing_rent                                        0.112457
# job_management/ self-employed/ highly qualified...  0.017085
# job_skilled employee / official                     0.000803
# job_unemployed/ unskilled - non-resident           -0.002221
# job_unskilled - resident                           -0.015082
# telephone_none                                      0.032836
# telephone_yes, registered under the customers n... -0.032836
# foreign_worker_no                                  -0.049557
# foreign_worker_yes                                  0.049557
#
#                                                     duration_in_month  \
# default                                                      0.259089
# duration_in_month                                            1.000000
# credit_amount                                                0.669686
# installment_as_income_perc                                   0.061521
# present_res_since                                            0.016471
# age                                                         -0.016886
# credits_this_bank                                           -0.034892
# people_under_maintenance                                    -0.052569
# account_check_status_0 <= ... < 200 DM                       0.114018
# account_check_status_< 0 DM                                 -0.020352
# account_check_status_>= 200 DM / salary assignm...          -0.069055
# account_check_status_no checking account                    -0.048893
# credit_history_all credits at this bank paid ba...           0.010133
# credit_history_critical account/ other credits ...          -0.072281
# credit_history_delay in paying off in the past               0.191216
# credit_history_existing credits paid back duly ...          -0.096088
# credit_history_no credits taken/ all credits pa...           0.145428
# purpose_(vacation - does not exist?)                        -0.012339
# purpose_business                                             0.199948
# purpose_car (new)                                           -0.091225
# purpose_car (used)                                           0.144163
# purpose_domestic appliances                                 -0.127981
# purpose_education                                           -0.006922
# purpose_furniture/equipment                                  0.148066
# purpose_radio/television                                    -0.037403
# purpose_repairs                                             -0.018768
# purpose_retraining                                          -0.054791
# savings_.. >= 1000 DM                                       -0.044526
# savings_... < 100 DM                                        -0.093842
# savings_100 <= ... < 500 DM                                  0.063088
# ...                                                               ...
# present_emp_since_.. >= 7 years                             -0.014401
# present_emp_since_... < 1 year                              -0.024813
# present_emp_since_1 <= ... < 4 years                        -0.004887
# present_emp_since_4 <= ... < 7 years                         0.060061
# present_emp_since_unemployed                                -0.018781
# personal_status_sex_female : divorced/separated...          -0.077797
# personal_status_sex_male : divorced/separated               -0.024679
# personal_status_sex_male : married/widowed                  -0.102467
# personal_status_sex_male : single                            0.144248
# other_debtors_co-applicant                                   0.046279
# other_debtors_guarantor                                     -0.068748
# other_debtors_none                                           0.014456
# property_if not A121 : building society savings...          -0.001235
# property_if not A121/A122 : car or other, not i...           0.069349
# property_real estate                                        -0.269293
# property_unknown / no property                               0.248034
# other_installment_plans_bank                                 0.090520
# other_installment_plans_none                                -0.128247
# other_installment_plans_stores                               0.088943
# housing_for free                                             0.194341
# housing_own                                                 -0.079168
# housing_rent                                                -0.066980
# job_management/ self-employed/ highly qualified...           0.107500
# job_skilled employee / official                              0.052840
# job_unemployed/ unskilled - non-resident                    -0.006085
# job_unskilled - resident                                    -0.155713
# telephone_none                                              -0.148593
# telephone_yes, registered under the customers n...           0.148593
# foreign_worker_no                                           -0.122827
# foreign_worker_yes                                           0.122827
#
#                                                     credit_amount  \
# default                                                  0.218535
# duration_in_month                                        0.669686
# credit_amount                                            1.000000
# installment_as_income_perc                              -0.254486
# present_res_since                                       -0.024982
# age                                                      0.047257
# credits_this_bank                                       -0.008663
# people_under_maintenance                                -0.008651
# account_check_status_0 <= ... < 200 DM                   0.143620
# account_check_status_< 0 DM                             -0.056465
# account_check_status_>= 200 DM / salary assignm...      -0.098673
# account_check_status_no checking account                -0.027248
# credit_history_all credits at this bank paid ba...      -0.030963
# credit_history_critical account/ other credits ...      -0.043385
# credit_history_delay in paying off in the past           0.166393
# credit_history_existing credits paid back duly ...      -0.105572
# credit_history_no credits taken/ all credits pa...       0.186404
# purpose_(vacation - does not exist?)                    -0.002046
# purpose_business                                         0.124325
# purpose_car (new)                                       -0.015854
# purpose_car (used)                                       0.200775
# purpose_domestic appliances                             -0.194202
# purpose_education                                       -0.022757
# purpose_furniture/equipment                              0.214410
# purpose_radio/television                                -0.024153
# purpose_repairs                                         -0.069743
# purpose_retraining                                      -0.077026
# savings_.. >= 1000 DM                                   -0.008967
# savings_... < 100 DM                                    -0.069427
# savings_100 <= ... < 500 DM                              0.013338
# ...                                                           ...
# present_emp_since_.. >= 7 years                         -0.028863
# present_emp_since_... < 1 year                          -0.050912
# present_emp_since_1 <= ... < 4 years                     0.003766
# present_emp_since_4 <= ... < 7 years                     0.063248
# present_emp_since_unemployed                             0.028110
# personal_status_sex_female : divorced/separated...      -0.106097
# personal_status_sex_male : divorced/separated            0.027282
# personal_status_sex_male : married/widowed              -0.163017
# personal_status_sex_male : single                        0.183556
# other_debtors_co-applicant                               0.077491
# other_debtors_guarantor                                 -0.100854
# other_debtors_none                                       0.014109
# property_if not A121 : building society savings...      -0.037872
# property_if not A121/A122 : car or other, not i...       0.030325
# property_real estate                                    -0.243379
# property_unknown / no property                           0.307632
# other_installment_plans_bank                             0.069236
# other_installment_plans_none                            -0.081737
# other_installment_plans_stores                           0.037394
# housing_for free                                         0.222785
# housing_own                                             -0.117212
# housing_rent                                            -0.045493
# job_management/ self-employed/ highly qualified...       0.334242
# job_skilled employee / official                         -0.107587
# job_unemployed/ unskilled - non-resident                -0.051660
# job_unskilled - resident                                -0.142962
# telephone_none                                          -0.286036
# telephone_yes, registered under the customers n...       0.286036
# foreign_worker_no                                       -0.004987
# foreign_worker_yes                                       0.004987
#
#                                                     installment_as_income_perc  \
# default                                                               0.053474
# duration_in_month                                                     0.061521
# credit_amount                                                        -0.254486
# installment_as_income_perc                                            1.000000
# present_res_since                                                     0.046631
# age                                                                   0.005176
# credits_this_bank                                                     0.013426
# people_under_maintenance                                             -0.066527
# account_check_status_0 <= ... < 200 DM                               -0.067434
# account_check_status_< 0 DM                                           0.066033
# account_check_status_>= 200 DM / salary assignm...                   -0.012067
# account_check_status_no checking account                              0.004990
# credit_history_all credits at this bank paid ba...                    0.123276
# credit_history_critical account/ other credits ...                    0.026525
# credit_history_delay in paying off in the past                       -0.074976
# credit_history_existing credits paid back duly ...                   -0.010059
# credit_history_no credits taken/ all credits pa...                   -0.076895
# purpose_(vacation - does not exist?)                                  0.019732
# purpose_business                                                      0.015560
# purpose_car (new)                                                    -0.037988
# purpose_car (used)                                                   -0.050575
# purpose_domestic appliances                                           0.093813
# purpose_education                                                     0.023491
# purpose_furniture/equipment                                          -0.027125
# purpose_radio/television                                             -0.062847
# purpose_repairs                                                       0.015614
# purpose_retraining                                                    0.021029
# savings_.. >= 1000 DM                                                 0.012365
# savings_... < 100 DM                                                 -0.004438
# savings_100 <= ... < 500 DM                                          -0.014921
# ...                                                                        ...
# present_emp_since_.. >= 7 years                                       0.146210
# present_emp_since_... < 1 year                                        0.004991
# present_emp_since_1 <= ... < 4 years                                 -0.105120
# present_emp_since_4 <= ... < 7 years                                  0.004819
# present_emp_since_unemployed                                         -0.073813
# personal_status_sex_female : divorced/separated...                   -0.043951
# personal_status_sex_male : divorced/separated                        -0.182660
# personal_status_sex_male : married/widowed                            0.057201
# personal_status_sex_male : single                                     0.087391
# other_debtors_co-applicant                                           -0.023244
# other_debtors_guarantor                                               0.064625
# other_debtors_none                                                   -0.028571
# property_if not A121 : building society savings...                   -0.012120
# property_if not A121/A122 : car or other, not i...                    0.004004
# property_real estate                                                 -0.020632
# property_unknown / no property                                        0.034169
# other_installment_plans_bank                                         -0.006174
# other_installment_plans_none                                         -0.018983
# other_installment_plans_stores                                        0.045879
# housing_for free                                                      0.020631
# housing_own                                                           0.024184
# housing_rent                                                         -0.045652
# job_management/ self-employed/ highly qualified...                    0.024764
# job_skilled employee / official                                       0.047316
# job_unemployed/ unskilled - non-resident                             -0.043179
# job_unskilled - resident                                             -0.061670
# telephone_none                                                        0.027533
# telephone_yes, registered under the customers n...                   -0.027533
# foreign_worker_no                                                    -0.099614
# foreign_worker_yes                                                    0.099614
#
#                                                     present_res_since  \
# default                                                     -0.041841
# duration_in_month                                            0.016471
# credit_amount                                               -0.024982
# installment_as_income_perc                                   0.046631
# present_res_since                                            1.000000
# age                                                          0.298441
# credits_this_bank                                            0.083938
# people_under_maintenance                                     0.062531
# account_check_status_0 <= ... < 200 DM                      -0.120421
# account_check_status_< 0 DM                                  0.099763
# account_check_status_>= 200 DM / salary assignm...          -0.016563
# account_check_status_no checking account                     0.023275
# credit_history_all credits at this bank paid ba...           0.024278
# credit_history_critical account/ other credits ...           0.102200
# credit_history_delay in paying off in the past              -0.043728
# credit_history_existing credits paid back duly ...          -0.082841
# credit_history_no credits taken/ all credits pa...           0.006119
# purpose_(vacation - does not exist?)                         0.055889
# purpose_business                                            -0.075164
# purpose_car (new)                                            0.054594
# purpose_car (used)                                           0.045543
# purpose_domestic appliances                                 -0.063447
# purpose_education                                            0.001697
# purpose_furniture/equipment                                  0.060521
# purpose_radio/television                                    -0.000984
# purpose_repairs                                             -0.025284
# purpose_retraining                                          -0.007735
# savings_.. >= 1000 DM                                       -0.038815
# savings_... < 100 DM                                        -0.101255
# savings_100 <= ... < 500 DM                                  0.032208
# ...                                                               ...
# present_emp_since_.. >= 7 years                              0.319913
# present_emp_since_... < 1 year                              -0.165567
# present_emp_since_1 <= ... < 4 years                        -0.130364
# present_emp_since_4 <= ... < 7 years                        -0.038704
# present_emp_since_unemployed                                 0.003577
# personal_status_sex_female : divorced/separated...          -0.000818
# personal_status_sex_male : divorced/separated               -0.088869
# personal_status_sex_male : married/widowed                  -0.079552
# personal_status_sex_male : single                            0.088419
# other_debtors_co-applicant                                  -0.012489
# other_debtors_guarantor                                     -0.024744
# other_debtors_none                                           0.026755
# property_if not A121 : building society savings...          -0.057403
# property_if not A121/A122 : car or other, not i...          -0.066149
# property_real estate                                        -0.041501
# property_unknown / no property                               0.202814
# other_installment_plans_bank                                 0.060053
# other_installment_plans_none                                -0.032041
# other_installment_plans_stores                              -0.040351
# housing_for free                                             0.251779
# housing_own                                                 -0.254912
# housing_rent                                                 0.093396
# job_management/ self-employed/ highly qualified...           0.056670
# job_skilled employee / official                             -0.068720
# job_unemployed/ unskilled - non-resident                    -0.033805
# job_unskilled - resident                                     0.046654
# telephone_none                                              -0.147116
# telephone_yes, registered under the customers n...           0.147116
# foreign_worker_no                                           -0.025856
# foreign_worker_yes                                           0.025856
#
#                                                          age  \
# default                                            -0.081586
# duration_in_month                                  -0.016886
# credit_amount                                       0.047257
# installment_as_income_perc                          0.005176
# present_res_since                                   0.298441
# age                                                 1.000000
# credits_this_bank                                   0.144156
# people_under_maintenance                            0.116705
# account_check_status_0 <= ... < 200 DM             -0.088513
# account_check_status_< 0 DM                        -0.003051
# account_check_status_>= 200 DM / salary assignm...  0.053409
# account_check_status_no checking account            0.055523
# credit_history_all credits at this bank paid ba...  0.007570
# credit_history_critical account/ other credits ...  0.165262
# credit_history_delay in paying off in the past      0.016991
# credit_history_existing credits paid back duly ... -0.178887
# credit_history_no credits taken/ all credits pa...  0.039647
# purpose_(vacation - does not exist?)                0.022546
# purpose_business                                   -0.006434
# purpose_car (new)                                   0.092582
# purpose_car (used)                                  0.041004
# purpose_domestic appliances                        -0.017986
# purpose_education                                   0.000113
# purpose_furniture/equipment                         0.070975
# purpose_radio/television                           -0.144410
# purpose_repairs                                     0.040817
# purpose_retraining                                 -0.021455
# savings_.. >= 1000 DM                              -0.029916
# savings_... < 100 DM                               -0.046285
# savings_100 <= ... < 500 DM                        -0.074008
# ...                                                      ...
# present_emp_since_.. >= 7 years                     0.352581
# present_emp_since_... < 1 year                     -0.245625
# present_emp_since_1 <= ... < 4 years               -0.145127
# present_emp_since_4 <= ... < 7 years               -0.080673
# present_emp_since_unemployed                        0.171042
# personal_status_sex_female : divorced/separated... -0.190711
# personal_status_sex_male : divorced/separated       0.079616
# personal_status_sex_male : married/widowed         -0.157038
# personal_status_sex_male : single                   0.234255
# other_debtors_co-applicant                         -0.034398
# other_debtors_guarantor                            -0.024299
# other_debtors_none                                  0.042641
# property_if not A121 : building society savings... -0.049969
# property_if not A121/A122 : car or other, not i... -0.185680
# property_real estate                                0.053873
# property_unknown / no property                      0.231474
# other_installment_plans_bank                        0.063272
# other_installment_plans_none                       -0.047448
# other_installment_plans_stores                     -0.016870
# housing_for free                                    0.277629
# housing_own                                         0.002890
# housing_rent                                       -0.232857
# job_management/ self-employed/ highly qualified...  0.193506
# job_skilled employee / official                    -0.220548
# job_unemployed/ unskilled - non-resident            0.092830
# job_unskilled - resident                            0.059427
# telephone_none                                     -0.151331
# telephone_yes, registered under the customers n...  0.151331
# foreign_worker_no                                   0.009335
# foreign_worker_yes                                 -0.009335
#
#                                                     credits_this_bank  \
# default                                                     -0.061375
# duration_in_month                                           -0.034892
# credit_amount                                               -0.008663
# installment_as_income_perc                                   0.013426
# present_res_since                                            0.083938
# age                                                          0.144156
# credits_this_bank                                            1.000000
# people_under_maintenance                                     0.090760
# account_check_status_0 <= ... < 200 DM                      -0.134189
# account_check_status_< 0 DM                                 -0.008866
# account_check_status_>= 200 DM / salary assignm...          -0.101759
# account_check_status_no checking account                     0.178287
# credit_history_all credits at this bank paid ba...          -0.111305
# credit_history_critical account/ other credits ...           0.540030
# credit_history_delay in paying off in the past               0.088432
# credit_history_existing credits paid back duly ...          -0.518437
# credit_history_no credits taken/ all credits pa...           0.064361
# purpose_(vacation - does not exist?)                        -0.043540
# purpose_business                                             0.103492
# purpose_car (new)                                            0.002279
# purpose_car (used)                                           0.022002
# purpose_domestic appliances                                 -0.059513
# purpose_education                                            0.074270
# purpose_furniture/equipment                                  0.024274
# purpose_radio/television                                    -0.030229
# purpose_repairs                                             -0.058479
# purpose_retraining                                           0.017095
# savings_.. >= 1000 DM                                        0.063913
# savings_... < 100 DM                                         0.060140
# savings_100 <= ... < 500 DM                                 -0.051355
# ...                                                               ...
# present_emp_since_.. >= 7 years                              0.142381
# present_emp_since_... < 1 year                              -0.096909
# present_emp_since_1 <= ... < 4 years                        -0.109873
# present_emp_since_4 <= ... < 7 years                         0.029995
# present_emp_since_unemployed                                 0.069447
# personal_status_sex_female : divorced/separated...          -0.073698
# personal_status_sex_male : divorced/separated               -0.017771
# personal_status_sex_male : married/widowed                  -0.074992
# personal_status_sex_male : single                            0.120827
# other_debtors_co-applicant                                   0.017018
# other_debtors_guarantor                                     -0.020533
# other_debtors_none                                           0.001955
# property_if not A121 : building society savings...           0.037863
# property_if not A121/A122 : car or other, not i...          -0.058871
# property_real estate                                         0.000457
# property_unknown / no property                               0.034148
# other_installment_plans_bank                                 0.035138
# other_installment_plans_none                                -0.062162
# other_installment_plans_stores                               0.057716
# housing_for free                                             0.058150
# housing_own                                                  0.041541
# housing_rent                                                -0.097184
# job_management/ self-employed/ highly qualified...           0.018928
# job_skilled employee / official                              0.008244
# job_unemployed/ unskilled - non-resident                     0.063727
# job_unskilled - resident                                    -0.051917
# telephone_none                                              -0.041090
# telephone_yes, registered under the customers n...           0.041090
# foreign_worker_no                                           -0.024385
# foreign_worker_yes                                           0.024385
#
#                                                     people_under_maintenance  \
# default                                                            -0.007916
# duration_in_month                                                  -0.052569
# credit_amount                                                      -0.008651
# installment_as_income_perc                                         -0.066527
# present_res_since                                                   0.062531
# age                                                                 0.116705
# credits_this_bank                                                   0.090760
# people_under_maintenance                                            1.000000
# account_check_status_0 <= ... < 200 DM                             -0.106872
# account_check_status_< 0 DM                                         0.076662
# account_check_status_>= 200 DM / salary assignm...                 -0.028040
# account_check_status_no checking account                            0.038246
# credit_history_all credits at this bank paid ba...                  0.037889
# credit_history_critical account/ other credits ...                  0.040665
# credit_history_delay in paying off in the past                      0.000582
# credit_history_existing credits paid back duly ...                 -0.055700
# credit_history_no credits taken/ all credits pa...                  0.003232
# purpose_(vacation - does not exist?)                                0.058670
# purpose_business                                                   -0.077542
# purpose_car (new)                                                   0.101391
# purpose_car (used)                                                  0.083631
# purpose_domestic appliances                                        -0.039000
# purpose_education                                                   0.020010
# purpose_furniture/equipment                                         0.027157
# purpose_radio/television                                           -0.085433
# purpose_repairs                                                    -0.057710
# purpose_retraining                                                 -0.040642
# savings_.. >= 1000 DM                                              -0.017167
# savings_... < 100 DM                                               -0.020890
# savings_100 <= ... < 500 DM                                         0.036672
# ...                                                                      ...
# present_emp_since_.. >= 7 years                                     0.105221
# present_emp_since_... < 1 year                                     -0.057487
# present_emp_since_1 <= ... < 4 years                               -0.036315
# present_emp_since_4 <= ... < 7 years                                0.024495
# present_emp_since_unemployed                                       -0.066741
# personal_status_sex_female : divorced/separated...                 -0.188485
# personal_status_sex_male : divorced/separated                      -0.105994
# personal_status_sex_male : married/widowed                         -0.133109
# personal_status_sex_male : single                                   0.300646
# other_debtors_co-applicant                                          0.002287
# other_debtors_guarantor                                             0.011414
# other_debtors_none                                                 -0.009773
# property_if not A121 : building society savings...                 -0.008920
# property_if not A121/A122 : car or other, not i...                 -0.058731
# property_real estate                                               -0.009602
# property_unknown / no property                                      0.098899
# other_installment_plans_bank                                        0.068964
# other_installment_plans_none                                       -0.065136
# other_installment_plans_stores                                      0.006750
# housing_for free                                                    0.135343
# housing_own                                                        -0.029047
# housing_rent                                                       -0.077498
# job_management/ self-employed/ highly qualified...                  0.011526
# job_skilled employee / official                                    -0.105317
# job_unemployed/ unskilled - non-resident                           -0.040484
# job_unskilled - resident                                            0.133109
# telephone_none                                                     -0.005313
# telephone_yes, registered under the customers n...                  0.005313
# foreign_worker_no                                                   0.099226
# foreign_worker_yes                                                 -0.099226
#
#                                                     account_check_status_0 <= ... < 200 DM  \
# default                                                                           0.116593
# duration_in_month                                                                 0.114018
# credit_amount                                                                     0.143620
# installment_as_income_perc                                                       -0.067434
# present_res_since                                                                -0.120421
# age                                                                              -0.088513
# credits_this_bank                                                                -0.134189
# people_under_maintenance                                                         -0.106872
# account_check_status_0 <= ... < 200 DM                                            1.000000
# account_check_status_< 0 DM                                                      -0.373070
# account_check_status_>= 200 DM / salary assignm...                               -0.150809
# account_check_status_no checking account                                         -0.472983
# credit_history_all credits at this bank paid ba...                               -0.034180
# credit_history_critical account/ other credits ...                               -0.154005
# credit_history_delay in paying off in the past                                    0.058527
# credit_history_existing credits paid back duly ...                                0.118514
# credit_history_no credits taken/ all credits pa...                                0.016386
# purpose_(vacation - does not exist?)                                              0.008223
# purpose_business                                                                  0.007029
# purpose_car (new)                                                                 0.006794
# purpose_car (used)                                                               -0.085454
# purpose_domestic appliances                                                       0.034399
# purpose_education                                                                 0.011556
# purpose_furniture/equipment                                                       0.107816
# purpose_radio/television                                                         -0.018337
# purpose_repairs                                                                  -0.038276
# purpose_retraining                                                               -0.001235
# savings_.. >= 1000 DM                                                             0.058027
# savings_... < 100 DM                                                             -0.020473
# savings_100 <= ... < 500 DM                                                       0.062311
# ...                                                                                    ...
# present_emp_since_.. >= 7 years                                                  -0.076590
# present_emp_since_... < 1 year                                                    0.110413
# present_emp_since_1 <= ... < 4 years                                             -0.000309
# present_emp_since_4 <= ... < 7 years                                             -0.030693
# present_emp_since_unemployed                                                      0.011293
# personal_status_sex_female : divorced/separated...                                0.071398
# personal_status_sex_male : divorced/separated                                     0.027741
# personal_status_sex_male : married/widowed                                        0.048882
# personal_status_sex_male : single                                                -0.107415
# other_debtors_co-applicant                                                        0.002450
# other_debtors_guarantor                                                           0.128488
# other_debtors_none                                                               -0.092788
# property_if not A121 : building society savings...                               -0.007046
# property_if not A121/A122 : car or other, not i...                               -0.009956
# property_real estate                                                              0.006289
# property_unknown / no property                                                    0.013034
# other_installment_plans_bank                                                      0.034652
# other_installment_plans_none                                                     -0.011451
# other_installment_plans_stores                                                   -0.036466
# housing_for free                                                                  0.002175
# housing_own                                                                      -0.016001
# housing_rent                                                                      0.017125
# job_management/ self-employed/ highly qualified...                                0.059625
# job_skilled employee / official                                                  -0.044042
# job_unemployed/ unskilled - non-resident                                          0.019352
# job_unskilled - resident                                                         -0.006874
# telephone_none                                                                   -0.009630
# telephone_yes, registered under the customers n...                                0.009630
# foreign_worker_no                                                                -0.054576
# foreign_worker_yes                                                                0.054576
#
#                                                     account_check_status_< 0 DM  \
# default                                                                0.245368
# duration_in_month                                                     -0.020352
# credit_amount                                                         -0.056465
# installment_as_income_perc                                             0.066033
# present_res_since                                                      0.099763
# age                                                                   -0.003051
# credits_this_bank                                                     -0.008866
# people_under_maintenance                                               0.076662
# account_check_status_0 <= ... < 200 DM                                -0.373070
# account_check_status_< 0 DM                                            1.000000
# account_check_status_>= 200 DM / salary assignm...                    -0.163512
# account_check_status_no checking account                              -0.512824
# credit_history_all credits at this bank paid ba...                     0.129540
# credit_history_critical account/ other credits ...                    -0.050117
# credit_history_delay in paying off in the past                        -0.093496
# credit_history_existing credits paid back duly ...                     0.021173
# credit_history_no credits taken/ all credits pa...                     0.051276
# purpose_(vacation - does not exist?)                                  -0.007236
# purpose_business                                                      -0.046229
# purpose_car (new)                                                      0.109672
# purpose_car (used)                                                    -0.061084
# purpose_domestic appliances                                           -0.167952
# purpose_education                                                      0.025915
# purpose_furniture/equipment                                           -0.010701
# purpose_radio/television                                               0.127295
# purpose_repairs                                                        0.059698
# purpose_retraining                                                     0.042043
# savings_.. >= 1000 DM                                                 -0.060067
# savings_... < 100 DM                                                   0.244841
# savings_100 <= ... < 500 DM                                           -0.114053
# ...                                                                         ...
# present_emp_since_.. >= 7 years                                       -0.013103
# present_emp_since_... < 1 year                                        -0.018844
# present_emp_since_1 <= ... < 4 years                                   0.004314
# present_emp_since_4 <= ... < 7 years                                  -0.002268
# present_emp_since_unemployed                                           0.050035
# personal_status_sex_female : divorced/separated...                     0.003638
# personal_status_sex_male : divorced/separated                          0.049970
# personal_status_sex_male : married/widowed                            -0.035333
# personal_status_sex_male : single                                     -0.004334
# other_debtors_co-applicant                                             0.007927
# other_debtors_guarantor                                                0.042980
# other_debtors_none                                                    -0.036294
# property_if not A121 : building society savings...                     0.054931
# property_if not A121/A122 : car or other, not i...                    -0.079363
# property_real estate                                                   0.009247
# property_unknown / no property                                         0.030868
# other_installment_plans_bank                                           0.031129
# other_installment_plans_none                                          -0.058400
# other_installment_plans_stores                                         0.057368
# housing_for free                                                       0.059252
# housing_own                                                           -0.123366
# housing_rent                                                           0.096931
# job_management/ self-employed/ highly qualified...                    -0.046998
# job_skilled employee / official                                       -0.006587
# job_unemployed/ unskilled - non-resident                               0.034859
# job_unskilled - resident                                               0.035333
# telephone_none                                                         0.112097
# telephone_yes, registered under the customers n...                    -0.112097
# foreign_worker_no                                                      0.060026
# foreign_worker_yes                                                    -0.060026
#
#                                                            ...          \
# default                                                    ...
# duration_in_month                                          ...
# credit_amount                                              ...
# installment_as_income_perc                                 ...
# present_res_since                                          ...
# age                                                        ...
# credits_this_bank                                          ...
# people_under_maintenance                                   ...
# account_check_status_0 <= ... < 200 DM                     ...
# account_check_status_< 0 DM                                ...
# account_check_status_>= 200 DM / salary assignm...         ...
# account_check_status_no checking account                   ...
# credit_history_all credits at this bank paid ba...         ...
# credit_history_critical account/ other credits ...         ...
# ...
# telephone_none                                            1.000000
# telephone_yes, registered under the customers n...       -1.000000
# foreign_worker_no                                         0.057757
# foreign_worker_yes                                       -0.057757
#
#                                                     telephone_yes, registered under the customers name   \
# default                                                                                     -0.032836
# duration_in_month                                                                            0.148593
# credit_amount                                                                                0.286036
# installment_as_income_perc                                                                  -0.027533
# present_res_since                                                                            0.147116
# age                                                                                          0.151331
# credits_this_bank                                                                            0.041090
# people_under_maintenance                                                                     0.005313
# account_check_status_0 <= ... < 200 DM                                                       0.009630
# account_check_status_< 0 DM                                                                 -0.112097
# account_check_status_>= 200 DM / salary assignm...                                          -0.060560
# account_check_status_no checking account                                                     0.125170
# credit_history_all credits at this bank paid ba...                                          -0.028542
# credit_history_critical account/ other credits ...                                           0.054212
# credit_history_delay in paying off in the past                                               0.020099
# credit_history_existing credits paid back duly ...                                          -0.040777
# credit_history_no credits taken/ all credits pa...                                          -0.020270
# purpose_(vacation - does not exist?)                                                         0.041065
# purpose_business                                                                             0.097338
# purpose_car (new)                                                                           -0.024249
# purpose_car (used)                                                                           0.124734
# purpose_domestic appliances                                                                 -0.090647
# purpose_education                                                                           -0.066259
# purpose_furniture/equipment                                                                  0.154238
# purpose_radio/television                                                                    -0.061791
# purpose_repairs                                                                             -0.008049
# purpose_retraining                                                                          -0.074244
# savings_.. >= 1000 DM                                                                       -0.049897
# savings_... < 100 DM                                                                        -0.082026
# savings_100 <= ... < 500 DM                                                                 -0.015100
# ...                                                                                               ...
# present_emp_since_.. >= 7 years                                                              0.092341
# present_emp_since_... < 1 year                                                              -0.044015
# present_emp_since_1 <= ... < 4 years                                                        -0.101438
# present_emp_since_4 <= ... < 7 years                                                         0.042440
# present_emp_since_unemployed                                                                 0.038785
# personal_status_sex_female : divorced/separated...                                          -0.072158
# personal_status_sex_male : divorced/separated                                                0.026487
# personal_status_sex_male : married/widowed                                                  -0.031223
# personal_status_sex_male : single                                                            0.073248
# other_debtors_co-applicant                                                                   0.012870
# other_debtors_guarantor                                                                     -0.112196
# other_debtors_none                                                                           0.069924
# property_if not A121 : building society savings...                                          -0.022316
# property_if not A121/A122 : car or other, not i...                                           0.087172
# property_real estate                                                                        -0.181613
# property_unknown / no property                                                               0.138412
# other_installment_plans_bank                                                                 0.016538
# other_installment_plans_none                                                                -0.036678
# other_installment_plans_stores                                                               0.041065
# housing_for free                                                                             0.120210
# housing_own                                                                                 -0.027550
# housing_rent                                                                                -0.066762
# job_management/ self-employed/ highly qualified...                                           0.414907
# job_skilled employee / official                                                             -0.083426
# job_unemployed/ unskilled - non-resident                                                    -0.058299
# job_unskilled - resident                                                                    -0.240285
# telephone_none                                                                              -1.000000
# telephone_yes, registered under the customers n...                                           1.000000
# foreign_worker_no                                                                           -0.057757
# foreign_worker_yes                                                                           0.057757
#
#                                                     foreign_worker_no  \
# default                                                     -0.049557
# duration_in_month                                           -0.122827
# credit_amount                                               -0.004987
# installment_as_income_perc                                  -0.099614
# present_res_since                                           -0.025856
# age                                                          0.009335
# credits_this_bank                                           -0.024385
# people_under_maintenance                                     0.099226
# account_check_status_0 <= ... < 200 DM                      -0.054576
# account_check_status_< 0 DM                                  0.060026
# account_check_status_>= 200 DM / salary assignm...           0.000377
# account_check_status_no checking account                    -0.007070
# credit_history_all credits at this bank paid ba...          -0.042583
# credit_history_critical account/ other credits ...           0.029757
# credit_history_delay in paying off in the past              -0.054340
# credit_history_existing credits paid back duly ...          -0.011660
# credit_history_no credits taken/ all credits pa...           0.091296
# purpose_(vacation - does not exist?)                        -0.039006
# purpose_business                                            -0.021709
# purpose_car (new)                                            0.182205
# purpose_car (used)                                          -0.059930
# purpose_domestic appliances                                 -0.039632
# purpose_education                                            0.038023
# purpose_furniture/equipment                                  0.067380
# purpose_radio/television                                    -0.088630
# purpose_repairs                                             -0.023185
# purpose_retraining                                          -0.016328
# savings_.. >= 1000 DM                                       -0.031975
# savings_... < 100 DM                                         0.020193
# savings_100 <= ... < 500 DM                                  0.097193
# ...                                                               ...
# present_emp_since_.. >= 7 years                             -0.027011
# present_emp_since_... < 1 year                              -0.025192
# present_emp_since_1 <= ... < 4 years                         0.107551
# present_emp_since_4 <= ... < 7 years                        -0.051307
# present_emp_since_unemployed                                -0.045116
# personal_status_sex_female : divorced/separated...          -0.093002
# personal_status_sex_male : divorced/separated                0.008598
# personal_status_sex_male : married/widowed                   0.053030
# personal_status_sex_male : single                            0.049541
# other_debtors_co-applicant                                  -0.039925
# other_debtors_guarantor                                      0.188536
# other_debtors_none                                          -0.103971
# property_if not A121 : building society savings...           0.018814
# property_if not A121/A122 : car or other, not i...          -0.131663
# property_real estate                                         0.133160
# property_unknown / no property                              -0.015533
# other_installment_plans_bank                                 0.027316
# other_installment_plans_none                                -0.003549
# other_installment_plans_stores                              -0.039006
# housing_for free                                            -0.065863
# housing_own                                                 -0.029757
# housing_rent                                                 0.089622
# job_management/ self-employed/ highly qualified...          -0.009839
# job_skilled employee / official                             -0.025420
# job_unemployed/ unskilled - non-resident                    -0.029706
# job_unskilled - resident                                     0.051136
# telephone_none                                               0.057757
# telephone_yes, registered under the customers n...          -0.057757
# foreign_worker_no                                            1.000000
# foreign_worker_yes                                          -1.000000
#
#                                                     foreign_worker_yes
# default                                                       0.049557
# duration_in_month                                             0.122827
# credit_amount                                                 0.004987
# installment_as_income_perc                                    0.099614
# present_res_since                                             0.025856
# age                                                          -0.009335
# credits_this_bank                                             0.024385
# people_under_maintenance                                     -0.099226
# account_check_status_0 <= ... < 200 DM                        0.054576
# account_check_status_< 0 DM                                  -0.060026
# account_check_status_>= 200 DM / salary assignm...           -0.000377
# account_check_status_no checking account                      0.007070
# credit_history_all credits at this bank paid ba...            0.042583
# credit_history_critical account/ other credits ...           -0.029757
# credit_history_delay in paying off in the past                0.054340
# credit_history_existing credits paid back duly ...            0.011660
# credit_history_no credits taken/ all credits pa...           -0.091296
# purpose_(vacation - does not exist?)                          0.039006
# purpose_business                                              0.021709
# purpose_car (new)                                            -0.182205
# purpose_car (used)                                            0.059930
# purpose_domestic appliances                                   0.039632
# purpose_education                                            -0.038023
# purpose_furniture/equipment                                  -0.067380
# purpose_radio/television                                      0.088630
# purpose_repairs                                               0.023185
# purpose_retraining                                            0.016328
# savings_.. >= 1000 DM                                         0.031975
# savings_... < 100 DM                                         -0.020193
# savings_100 <= ... < 500 DM                                  -0.097193
# ...                                                                ...
# present_emp_since_.. >= 7 years                               0.027011
# present_emp_since_... < 1 year                                0.025192
# present_emp_since_1 <= ... < 4 years                         -0.107551
# present_emp_since_4 <= ... < 7 years                          0.051307
# present_emp_since_unemployed                                  0.045116
# personal_status_sex_female : divorced/separated...            0.093002
# personal_status_sex_male : divorced/separated                -0.008598
# personal_status_sex_male : married/widowed                   -0.053030
# personal_status_sex_male : single                            -0.049541
# other_debtors_co-applicant                                    0.039925
# other_debtors_guarantor                                      -0.188536
# other_debtors_none                                            0.103971
# property_if not A121 : building society savings...           -0.018814
# property_if not A121/A122 : car or other, not i...            0.131663
# property_real estate                                         -0.133160
# property_unknown / no property                                0.015533
# other_installment_plans_bank                                 -0.027316
# other_installment_plans_none                                  0.003549
# other_installment_plans_stores                                0.039006
# housing_for free                                              0.065863
# housing_own                                                   0.029757
# housing_rent                                                 -0.089622
# job_management/ self-employed/ highly qualified...            0.009839
# job_skilled employee / official                               0.025420
# job_unemployed/ unskilled - non-resident                      0.029706
# job_unskilled - resident                                     -0.051136
# telephone_none                                               -0.057757
# telephone_yes, registered under the customers n...            0.057757
# foreign_worker_no                                            -1.000000
# foreign_worker_yes                                            1.000000
#
# [62 rows x 62 columns]

# %% [markdown]
# ### Drop the original variables which are converted to dummy

# %%
GermanCredit_train_D = pd.get_dummies(GermanCredit_train,drop_first=True)
GermanCredit_train_D.head().T
# Out:
#                                                      262   457   82     563  \
# default                                                0     1     0      1
# duration_in_month                                     18    12    18     36
# credit_amount                                       5302  3386  1568  12389
# installment_as_income_perc                             2     3     3      1
# present_res_since                                      4     4     4      4
# age                                                   36    35    24     37
# credits_this_bank                                      3     1     1      1
# people_under_maintenance                               1     1     1      1
# account_check_status_< 0 DM                            1     1     0      0
# account_check_status_>= 200 DM / salary assignm...     0     0     0      0
# account_check_status_no checking account               0     0     1      0
# credit_history_critical account/ other credits ...     1     0     0      0
# credit_history_delay in paying off in the past         0     0     0      0
# credit_history_existing credits paid back duly ...     0     1     1      1
# credit_history_no credits taken/ all credits pa...     0     0     0      0
# purpose_business                                       0     0     1      0
# purpose_car (new)                                      1     0     0      1
# purpose_car (used)                                     0     1     0      0
# purpose_domestic appliances                            0     0     0      0
# purpose_education                                      0     0     0      0
# purpose_furniture/equipment                            0     0     0      0
# purpose_radio/television                               0     0     0      0
# purpose_repairs                                        0     0     0      0
# purpose_retraining                                     0     0     0      0
# savings_... < 100 DM                                   1     1     0      0
# savings_100 <= ... < 500 DM                            0     0     1      0
# savings_500 <= ... < 1000 DM                           0     0     0      0
# savings_unknown/ no savings account                    0     0     0      1
# present_emp_since_... < 1 year                         0     0     0      0
# present_emp_since_1 <= ... < 4 years                   0     0     1      1
# present_emp_since_4 <= ... < 7 years                   0     0     0      0
# present_emp_since_unemployed                           0     0     0      0
# personal_status_sex_male : divorced/separated          0     0     0      0
# personal_status_sex_male : married/widowed             0     0     0      0
# personal_status_sex_male : single                      1     1     0      1
# other_debtors_guarantor                                0     0     0      0
# other_debtors_none                                     1     1     1      1
# property_if not A121/A122 : car or other, not i...     0     0     0      0
# property_real estate                                   0     0     0      0
# property_unknown / no property                         1     1     0      1
# other_installment_plans_none                           1     1     1      1
# other_installment_plans_stores                         0     0     0      0
# housing_own                                            0     0     0      0
# housing_rent                                           0     0     1      0
# job_skilled employee / official                        0     1     0      1
# job_unemployed/ unskilled - non-resident               0     0     0      0
# job_unskilled - resident                               0     0     1      0
# telephone_yes, registered under the customers n...     1     1     0      1
# foreign_worker_yes                                     1     1     1      1
#
#                                                      407
# default                                                0
# duration_in_month                                     15
# credit_amount                                       1053
# installment_as_income_perc                             4
# present_res_since                                      2
# age                                                   27
# credits_this_bank                                      1
# people_under_maintenance                               1
# account_check_status_< 0 DM                            1
# account_check_status_>= 200 DM / salary assignm...     0
# account_check_status_no checking account               0
# credit_history_critical account/ other credits ...     0
# credit_history_delay in paying off in the past         0
# credit_history_existing credits paid back duly ...     1
# credit_history_no credits taken/ all credits pa...     0
# purpose_business                                       0
# purpose_car (new)                                      0
# purpose_car (used)                                     0
# purpose_domestic appliances                            1
# purpose_education                                      0
# purpose_furniture/equipment                            0
# purpose_radio/television                               0
# purpose_repairs                                        0
# purpose_retraining                                     0
# savings_... < 100 DM                                   1
# savings_100 <= ... < 500 DM                            0
# savings_500 <= ... < 1000 DM                           0
# savings_unknown/ no savings account                    0
# present_emp_since_... < 1 year                         1
# present_emp_since_1 <= ... < 4 years                   0
# present_emp_since_4 <= ... < 7 years                   0
# present_emp_since_unemployed                           0
# personal_status_sex_male : divorced/separated          0
# personal_status_sex_male : married/widowed             1
# personal_status_sex_male : single                      0
# other_debtors_guarantor                                0
# other_debtors_none                                     1
# property_if not A121/A122 : car or other, not i...     0
# property_real estate                                   1
# property_unknown / no property                         0
# other_installment_plans_none                           1
# other_installment_plans_stores                         0
# housing_own                                            1
# housing_rent                                           0
# job_skilled employee / official                        1
# job_unemployed/ unskilled - non-resident               0
# job_unskilled - resident                               0
# telephone_yes, registered under the customers n...     0
# foreign_worker_yes                                     0

# %% [markdown]
# ### Q3 Split Train/Test data 70:30 ratio( 1 Marks)
# ##### Hint:from sklearn.model_selection import train_test_split

# %%
GermanCredit_train_D.shape
# Out:
# (500, 49)

# %%
from scipy.stats import zscore
X = GermanCredit_train_D.drop("default", axis=1)
y = GermanCredit_train_D[["default"]]
#X = X.apply(zscore)

X_train, X_test , y_train, y_test = train_test_split(X,y,test_size = 0.30 , random_state = 7)

# %%
X.head()
# Out:
#      duration_in_month  credit_amount  installment_as_income_perc  \
# 262                 18           5302                           2
# 457                 12           3386                           3
# 82                  18           1568                           3
# 563                 36          12389                           1
# 407                 15           1053                           4
#
#      present_res_since  age  credits_this_bank  people_under_maintenance  \
# 262                  4   36                  3                         1
# 457                  4   35                  1                         1
# 82                   4   24                  1                         1
# 563                  4   37                  1                         1
# 407                  2   27                  1                         1
#
#      account_check_status_< 0 DM  \
# 262                            1
# 457                            1
# 82                             0
# 563                            0
# 407                            1
#
#      account_check_status_>= 200 DM / salary assignments for at least 1 year  \
# 262                                                  0
# 457                                                  0
# 82                                                   0
# 563                                                  0
# 407                                                  0
#
#      account_check_status_no checking account         ...          \
# 262                                         0         ...
# 457                                         0         ...
# 82                                          1         ...
# 563                                         0         ...
# 407                                         0         ...
#
#      property_unknown / no property  other_installment_plans_none  \
# 262                               1                             1
# 457                               1                             1
# 82                                0                             1
# 563                               1                             1
# 407                               0                             1
#
#      other_installment_plans_stores  housing_own  housing_rent  \
# 262                               0            0             0
# 457                               0            0             0
# 82                                0            0             1
# 563                               0            0             0
# 407                               0            1             0
#
#      job_skilled employee / official  \
# 262                                0
# 457                                1
# 82                                 0
# 563                                1
# 407                                1
#
#      job_unemployed/ unskilled - non-resident  job_unskilled - resident  \
# 262                                         0                         0
# 457                                         0                         0
# 82                                          0                         1
# 563                                         0                         0
# 407                                         0                         0
#
#      telephone_yes, registered under the customers name   foreign_worker_yes
# 262                                                  1                     1
# 457                                                  1                     1
# 82                                                   0                     1
# 563                                                  1                     1
# 407                                                  0                     0
#
# [5 rows x 48 columns]

# %% [markdown]
# ### Q4 Build Random Forest Model( 1 Marks)
# #### Hint:from sklearn.ensemble import RandomForestClassifier using n_jobs=2,n_estimators=500,criterion="entropy",random_state=9999

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Rf_model = RandomForestClassifier(n_estimators=500,criterion='entropy',n_jobs=2,random_state=9999 )
Rf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=2,
#             oob_score=False, random_state=9999, verbose=0,
#             warm_start=False)

# %% [markdown]
# ### Q5 Calculate Confusion Matrix and Accuracy score (1 Marks)
# ##### Hint: Use confusion_matrix and accuracy_score

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, precision_score, f1_score, auc


y_pred=Rf_model.predict(X_test)
acc1=metrics.accuracy_score(y_test,y_pred)
print('Test data accuracy : ' ,acc1)
# Out:
# Test data accuracy :  0.7333333333333333

# %%
X_pred=Rf_model.predict(X_train)
acc1=metrics.accuracy_score(y_train,X_pred)
print('Train data accuracy : ' , acc1)
# Out:
# Train data accuracy :  1.0

# %%
cm=metrics.confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[98  5]
#  [35 12]]

# %% [markdown]
# ### Q6 Show the list of the features importance( 1 Marks)

# %%
feature_importances = pd.DataFrame(Rf_model.feature_importances_,
                                   index = X.columns,
                                    columns=['importance']).sort_values('importance', ascending=False)
feature_importances
# Out:
#                                                     importance
# credit_amount                                         0.125224
# duration_in_month                                     0.092313
# age                                                   0.087226
# account_check_status_no checking account              0.062103
# installment_as_income_perc                            0.041379
# present_res_since                                     0.037270
# account_check_status_< 0 DM                           0.028065
# personal_status_sex_male : single                     0.024842
# other_installment_plans_none                          0.022624
# credits_this_bank                                     0.021628
# savings_... < 100 DM                                  0.021410
# job_skilled employee / official                       0.020469
# property_real estate                                  0.019926
# telephone_yes, registered under the customers n...    0.019164
# credit_history_critical account/ other credits ...    0.018578
# housing_own                                           0.018282
# savings_unknown/ no savings account                   0.017970
# people_under_maintenance                              0.017597
# property_if not A121/A122 : car or other, not i...    0.017152
# credit_history_existing credits paid back duly ...    0.016623
# present_emp_since_1 <= ... < 4 years                  0.016369
# purpose_domestic appliances                           0.016368
# present_emp_since_... < 1 year                        0.015712
# purpose_car (new)                                     0.015678
# present_emp_since_4 <= ... < 7 years                  0.015129
# property_unknown / no property                        0.014405
# purpose_radio/television                              0.014220
# job_unskilled - resident                              0.013857
# housing_rent                                          0.012924
# credit_history_delay in paying off in the past        0.011144
# other_debtors_none                                    0.010807
# purpose_business                                      0.010770
# purpose_car (used)                                    0.010492
# personal_status_sex_male : married/widowed            0.010425
# account_check_status_>= 200 DM / salary assignm...    0.010364
# savings_100 <= ... < 500 DM                           0.009095
# other_installment_plans_stores                        0.008949
# other_debtors_guarantor                               0.007795
# credit_history_no credits taken/ all credits pa...    0.007775
# present_emp_since_unemployed                          0.007680
# savings_500 <= ... < 1000 DM                          0.007512
# personal_status_sex_male : divorced/separated         0.006371
# purpose_education                                     0.003748
# job_unemployed/ unskilled - non-resident              0.003106
# purpose_repairs                                       0.002757
# foreign_worker_yes                                    0.002474
# purpose_furniture/equipment                           0.002433
# purpose_retraining                                    0.001796

# %% [markdown]
# ### Q7 K-fold cross-validation( 2 Marks)
# ##### k-fold cross validation( without stratification)
# ##### Usually k is set as 10-20 in practical settings, depends on data set size

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
# Use below values
num_folds = 10
seed = 77
kf=KFold(n_splits=10,shuffle=True,random_state=seed)
#print(kf.split(X,y))

# %%
#Validate the Random Forest model build above using k fold

# %%
from sklearn.model_selection import KFold  
from sklearn import metrics  
#kf=KFold(n_splits=num_folds,shuffle=True,random_state=77)   
list_mse=[]  
sc=StandardScaler() 
X=sc.fit_transform(X) 
Y=sc.fit_transform(y) 
X=X.astype('int') 
Y=Y.astype('int')    
Accuracy_score=[]      
for train,test in kf.split(X,Y):              
    Xtrain,Xtest=X[train,:],X[test,:]              
    Ytrain,Ytest=Y[train],Y[test]                 
    Rf_model.fit(Xtrain,Ytrain)              
    Y_predict = Rf_model.predict(Xtest)              
    #mse=np.sum((Ytest-Y_predict)**2)/len(Ytest)             
    #mse=metrics.mean_squared_error(Ytest,Y_predict)     
    acc1=metrics.accuracy_score(Ytest,Y_predict)
    Accuracy_score.append(acc1) 
    print(acc1) 
    
print("Mean Accuracy score: %0.02f (+/- %0.5f) [%s]" % (np.mean(Accuracy_score), np.std(Accuracy_score), 'RF' ))
# Out:
# 0.72
# 0.64
# 0.7
# 0.78
# 0.68
# 0.78
# 0.84
# 0.74
# 0.72
# 0.6
# Mean Accuracy score: 0.72 (+/- 0.06693) [RF]

# %%
#Calculate Mean score

# %%
print("Mean Accuracy score: %0.02f [%s]" % (np.mean(Accuracy_score), 'RF' ))
# Out:
# Mean Accuracy score: 0.72 [RF]

# %%
# Calculate score standard deviation using std()

# %%
print("Std deviation Accuracy score: %0.02f [%s]" % (np.std(Accuracy_score), 'RF' ))
# Out:
# Std deviation Accuracy score: 0.07 [RF]

# %% [markdown]
# # Q8 Print the confusion matrix( 1 Marks)

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = Rf_model, X = X_test, y = y_test, cv = num_folds)
print(accuracies.mean())
print(accuracies.std())
# Out:
# 0.7080952380952381
# 0.07388590517904604

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix

y_pred = cross_val_predict(estimator = Rf_model, X = X_test, y = y_test, cv = num_folds)
conf_mat = confusion_matrix(y_test, y_pred)

#Confusion Matrix
conf_mat
# Out:
# array([[96,  7],
#        [37, 10]], dtype=int64)

# %% [markdown]
# # Q9.Classification accuracy:
# percentage of correct predictions and Calculate sensitivity (or True Positive Rate or Recall) and Precision.
# ( 1 Marks)

# %%
# calculate accuracy
from sklearn import metrics
print(metrics.accuracy_score(y_test, y_pred))

print("Accuracy: %0.2f (+/- %0.2f)" % (accuracies.mean(), accuracies.std() * 2))

#print(metrics.confusion_matrix(y_train, y_pred))

TP = conf_mat[1, 1]
TN = conf_mat[0, 0]
FP = conf_mat[0, 1]
FN = conf_mat[1, 0]

#TP = 12
#TN = 192
#FP = 22
#FN = 74

print(' Percentage of correct predictions:  ',((TP + TN) / float(TP + TN + FP + FN) * 100))
# Out:
# 0.7066666666666667
# Accuracy: 0.71 (+/- 0.15)
#  Percentage of correct predictions:   70.66666666666667

# %%
#Sensitivity
sensitivity = TP / float(FN + TP)

print(sensitivity)
print(metrics.recall_score(y_test, y_pred))
# Out:
# 0.2127659574468085
# 0.2127659574468085

# %% [markdown]
# # Q10.Plot Receiver Operating Characteristic (ROC) Curves( 1 Marks)

# %%
#Hint: Use roc_curve

# %%
#Hint: Use roc_curve 
from sklearn.metrics import roc_curve, auc 
y_predictProb = Rf_model.predict_proba(X_test) 
fpr, tpr, thresholds = roc_curve(y_test, y_predictProb[::,1]) 
roc_auc = auc(fpr, tpr) 
roc_auc
# Out:
# 0.7589341045238587

# %%
plt.plot(fpr, tpr,  color='darkorange', label='ROC curve (area = %0.2f)' % roc_auc) 
plt.plot([0, 1], [0, 1], color='navy', linestyle='--') 
plt.xlabel('False Positive Rate') 
plt.ylabel('True Positive Rate') 
plt.title('Receiver operating characteristic') 
plt.legend(loc="lower right")

# %% [markdown]
# ROC curve can help you to choose a threshold that balances sensitivity and specificity in a way that makes sense for your particular context

# %% [markdown]
# # Q11. Calculate AUC(the percentage of the ROC plot that is underneath the curve) - optional

# %%
# IMPORTANT: first argument is true values, second argument is predicted probabilities
print(metrics.roc_auc_score(y_test, y_pred))
# Out:
# 0.5724023961991325

# %% [markdown]
# ### Bootstrapping ( Bonus)
# ##### Given a dataset of size n, a bootstrap sample is created by sampling n instances uniformly from the data (with/without replacement)
# ##### Create a model with each bootstrap sample and validate it with the test set
# ##### Final result is calculated by averaging the accuracy of models

# %%
# Number of iterations for bootstrapping
bootstrap_iteration = 10
accuracy = []

# %%
from sklearn.utils import resample
from sklearn.metrics import accuracy_score

for i in range(bootstrap_iteration):
    X_, y_ = resample(X_train, y_train)
    Rf_model.fit(X_, y_)
    y_pred = Rf_model.predict(X_test)
    
    acc = accuracy_score(y_pred, y_test)
    accuracy.append(acc)

# %%
accuracy = np.array(accuracy)
print('Accuracy Score')
print('Avearge: ', accuracy.mean())
print('Standard deviation: ', accuracy.std())
# Out:
# Accuracy Score
# Avearge:  0.7393333333333334
# Standard deviation:  0.02240039682188192
